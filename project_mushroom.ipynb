# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('mushroom.csv',names=['edibility','cap-shape','cap-surface','cap-color','bruises','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat'])

# %%
ds
# Out:
#      edibility cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            p         x           s         n       t    p               f
# 1            e         x           s         y       t    a               f
# 2            e         b           s         w       t    l               f
# 3            p         x           y         w       t    p               f
# 4            e         x           s         g       f    n               f
# ...        ...       ...         ...       ...     ...  ...             ...
# 8119         e         k           s         n       f    n               a
# 8120         e         x           s         n       f    n               a
# 8121         e         f           s         n       f    n               a
# 8122         p         k           y         n       f    y               f
# 8123         e         x           s         n       f    n               a
#
# ...

# %%
ds.isnull().sum()
# Out:
# edibility                   0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#since all the data are categorical form we have to encode them using label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in ds.columns:
    ds[i]=le.fit_transform(ds[i])

# %%
ds
# Out:
#       edibility  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             1          5            2          4        1     6
# 1             0          5            2          9        1     0
# 2             0          0            2          8        1     3
# 3             1          5            3          8        1     6
# 4             0          5            2          3        0     5
# ...         ...        ...          ...        ...      ...   ...
# 8119          0          3            2          4        0     5
# 8120          0          5            2          4        0     5
# 8121          0          2            2          4        0     5
# 8122          1          3            3          4        0     8
# 8123          0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   edibility                 8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %%
ds.describe()
# Out:
#          edibility    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds.corr()
# Out:
#                           edibility  cap-shape  cap-surface  cap-color  \
# edibility                  1.000000   0.052951     0.178446  -0.031384
# cap-shape                  0.052951   1.000000    -0.050454  -0.048203
# cap-surface                0.178446  -0.050454     1.000000  -0.019402
# cap-color                 -0.031384  -0.048203    -0.019402   1.000000
# bruises                   -0.501530  -0.035374     0.070228  -0.000764
# odor                      -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment            0.129200   0.078865    -0.034180   0.041436
# gill-spacing              -0.348387   0.013196    -0.282306   0.144259
# gill-size                  0.540024   0.054050     0.208100  -0.169464
# gill-color                -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape               -0.102019   0.063794    -0.014123  -0.456496
# stalk-root                -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
sns.heatmap(ds.corr())

# %%
#since veil-type has no correlation with any attributes we can drop the column
ds.drop(['veil-type'],axis=1,inplace=True)

# %%
ds
# Out:
#       edibility  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             1          5            2          4        1     6
# 1             0          5            2          9        1     0
# 2             0          0            2          8        1     3
# 3             1          5            3          8        1     6
# 4             0          5            2          3        0     5
# ...         ...        ...          ...        ...      ...   ...
# 8119          0          3            2          4        0     5
# 8120          0          5            2          4        0     5
# 8121          0          2            2          4        0     5
# 8122          1          3            3          4        0     8
# 8123          0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# ...

# %%
ds.corr()
# Out:
#                           edibility  cap-shape  cap-surface  cap-color  \
# edibility                  1.000000   0.052951     0.178446  -0.031384
# cap-shape                  0.052951   1.000000    -0.050454  -0.048203
# cap-surface                0.178446  -0.050454     1.000000  -0.019402
# cap-color                 -0.031384  -0.048203    -0.019402   1.000000
# bruises                   -0.501530  -0.035374     0.070228  -0.000764
# odor                      -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment            0.129200   0.078865    -0.034180   0.041436
# gill-spacing              -0.348387   0.013196    -0.282306   0.144259
# gill-size                  0.540024   0.054050     0.208100  -0.169464
# gill-color                -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape               -0.102019   0.063794    -0.014123  -0.456496
# stalk-root                -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
ds.describe()
# Out:
#          edibility    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
sns.heatmap(ds.corr())

# %%
plt.figure(figsize=(15,15))
sns.heatmap(ds.corr(),annot=True)

# %%
for i in ds.columns:
    plt.figure()
    ds.boxplot([i])

# %%
#here we can find outliers in various attributes.hence we have tot treat them
from scipy.stats import zscore
z_score=abs(zscore(ds))
print(ds.shape)

ds_final=ds.loc[(z_score<3).all(axis=1)]
print(ds_final.shape)
# Out:
# (8124, 22)
# (6568, 22)

# %%
ds=ds_final    #we have removed the outliers
ds
# Out:
#       edibility  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             1          5            2          4        1     6
# 1             0          5            2          9        1     0
# 2             0          0            2          8        1     3
# 3             1          5            3          8        1     6
# 4             0          5            2          3        0     5
# ...         ...        ...          ...        ...      ...   ...
# 8113          1          3            3          2        0     8
# 8116          1          3            3          4        0     7
# 8117          1          3            2          2        0     8
# 8118          1          3            3          4        0     2
# 8122          1          3            3          4        0     8
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# ...

# %%
ds.shape
# Out:
# (6568, 22)

# %%
ds.skew()
# Out:
# edibility                   0.124508
# cap-shape                  -0.234646
# cap-surface                -0.630373
# cap-color                   0.811934
# bruises                     0.124508
# odor                       -0.172451
# gill-attachment             0.000000
# gill-spacing                1.910296
# gill-size                   0.489136
# gill-color                  0.048010
# stalk-shape                -0.881319
# stalk-root                  0.777382
# stalk-surface-above-ring   -1.381335
# stalk-surface-below-ring   -0.989929
# stalk-color-above-ring     -1.776145
# stalk-color-below-ring     -1.681096
# veil-color                  0.000000
# ring-number                 0.000000
# ring-type                  -0.231353
# spore-print-color           0.697445
# population                 -1.737467
# habitat                     0.987162
# dtype: float64

# %%
sns.lineplot(x='cap-shape',y='edibility',data=ds)

# %%
sns.lineplot(x='cap-color',y='edibility',data=ds)

# %% [markdown]
# sns.lineplot(x='odor',y='edibility',data=ds)

# %%
sns.lineplot(x='cap-surface',y='edibility',data=ds)

# %%
sns.lineplot(x='gill-spacing',y='edibility',data=ds)

# %%
sns.lineplot(x='habitat',y='edibility',data=ds)

# %%
for i in ds.columns:
    plt.figure()
    sns.distplot(ds[i])

# %% [markdown]
# Training the model

# %%
x=ds.iloc[:,1:]
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8113          3            3          2        0     8                1
# 8116          3            3          4        0     7                1
# 8117          3            2          2        0     8                1
# 8118          3            3          4        0     2                1
# 8122          3            3          4        0     8                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y=ds['edibility']
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8113    1
# 8116    1
# 8117    1
# 8118    1
# 8122    1
# Name: edibility, Length: 6568, dtype: int32

# %%
x.skew()
# Out:
# cap-shape                  -0.234646
# cap-surface                -0.630373
# cap-color                   0.811934
# bruises                     0.124508
# odor                       -0.172451
# gill-attachment             0.000000
# gill-spacing                1.910296
# gill-size                   0.489136
# gill-color                  0.048010
# stalk-shape                -0.881319
# stalk-root                  0.777382
# stalk-surface-above-ring   -1.381335
# stalk-surface-below-ring   -0.989929
# stalk-color-above-ring     -1.776145
# stalk-color-below-ring     -1.681096
# veil-color                  0.000000
# ring-number                 0.000000
# ring-type                  -0.231353
# spore-print-color           0.697445
# population                 -1.737467
# habitat                     0.987162
# dtype: float64

# %%
x.shape
# Out:
# (6568, 21)

# %%
y.shape
# Out:
# (6568,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=.18,random_state=53)

# %%
train_x.shape
# Out:
# (5385, 21)

# %%
train_y.shape
# Out:
# (5385,)

# %%
test_x.shape
# Out:
# (1183, 21)

# %%
test_y.shape
# Out:
# (1183,)

# %%
#Logistic Regression
lg=LogisticRegression()
lg.fit(train_x,train_y)
predlr=lg.predict(test_x)

print('Accuracy score:',accuracy_score(test_y,predlr))
print('Confusion matrix:\n',confusion_matrix(test_y,predlr))
print('Classification report:\n',classification_report(test_y,predlr))
# Out:
# Accuracy score: 0.9678782755705833
# Confusion matrix:
#  [[618  22]
#  [ 16 527]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       640
#            1       0.96      0.97      0.97       543
#
#     accuracy                           0.97      1183
#    macro avg       0.97      0.97      0.97      1183
# weighted avg       0.97      0.97      0.97      1183

# %%
#GaussianNB
gnb=GaussianNB()
gnb.fit(train_x,train_y)
predgnb=gnb.predict(test_x)

print('Accuracy score:',accuracy_score(test_y,predgnb))
print('Confusion matrix:\n',confusion_matrix(test_y,predgnb))
print('Classification report:\n',classification_report(test_y,predgnb))
# Out:
# Accuracy score: 0.8985629754860525
# Confusion matrix:
#  [[608  32]
#  [ 88 455]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       640
#            1       0.93      0.84      0.88       543
#
#     accuracy                           0.90      1183
#    macro avg       0.90      0.89      0.90      1183
# weighted avg       0.90      0.90      0.90      1183

# %%
#Decision tree classifier
dtc=DecisionTreeClassifier()
dtc.fit(train_x,train_y)
dtc.score(train_x,train_y)
preddtc=dtc.predict(test_x)

print('Accuracy score:',accuracy_score(test_y,preddtc))
print('Confusion matrix:\n',confusion_matrix(test_y,preddtc))
print('Classification report:\n',classification_report(test_y,preddtc))
# Out:
# Accuracy score: 1.0
# Confusion matrix:
#  [[640   0]
#  [  0 543]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       640
#            1       1.00      1.00      1.00       543
#
#     accuracy                           1.00      1183
#    macro avg       1.00      1.00      1.00      1183
# weighted avg       1.00      1.00      1.00      1183

# %%
#KNearest neighbors
knn=KNeighborsClassifier()
knn.fit(train_x,train_y)
knn.score(train_x,train_y)
predknn=knn.predict(test_x)

print('Accuracy score:',accuracy_score(test_y,predknn))
print('Confusion matrix:\n',confusion_matrix(test_y,predknn))
print('Classification report:\n',classification_report(test_y,predknn))
# Out:
# Accuracy score: 0.9983093829247676
# Confusion matrix:
#  [[638   2]
#  [  0 543]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       640
#            1       1.00      1.00      1.00       543
#
#     accuracy                           1.00      1183
#    macro avg       1.00      1.00      1.00      1183
# weighted avg       1.00      1.00      1.00      1183

# %%
#we can create a fn inorder to find the metrics for different kernels of SVM Classifier
def svmkernel(ker):
    svc=SVC(kernel=ker)
    svc.fit(train_x,train_y)
    svc.score(train_x,train_y)
    predsvc=svc.predict(test_x)
    
    print('Accuracy score:',accuracy_score(test_y,predsvc))
    print('Confusion matrix:\n',confusion_matrix(test_y,predsvc))
    print('Classification report:\n',classification_report(test_y,predsvc))

# %%
svmkernel('rbf')
# Out:
# Accuracy score: 1.0
# Confusion matrix:
#  [[640   0]
#  [  0 543]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       640
#            1       1.00      1.00      1.00       543
#
#     accuracy                           1.00      1183
#    macro avg       1.00      1.00      1.00      1183
# weighted avg       1.00      1.00      1.00      1183

# %%
svmkernel('poly')
# Out:
# Accuracy score: 1.0
# Confusion matrix:
#  [[640   0]
#  [  0 543]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       640
#            1       1.00      1.00      1.00       543
#
#     accuracy                           1.00      1183
#    macro avg       1.00      1.00      1.00      1183
# weighted avg       1.00      1.00      1.00      1183

# %% [markdown]
# ## Inference

# %% [markdown]
# The mushroom dataset has been trained for various classifier models and its corresponding metrics has been calculated.The accuracy score of various models are:
#
# Logistic Regression= 0.9678782755705833
#
# GaussianNB= 0.8985629754860525
#
# Decision Tree Classifier= 1.0
#
# KNearest Neighbors= 0.9983093829247676
#
# svc(kernel='rbf')= 1.0
#
# svc(kernel='poly')= 1.0
#
# From the above inferences we can conclude that Decision Tree Classifier and Support vector machine are the suitable models for this dataset which are yielding an accuraccy score of 1.0
